# %% [markdown]
# ## IMAGE PROCESSING

# %%
#pip install opencv-python

# %%
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
from PIL import Image

# %%
import cv2

# %%
img = cv2.imread(r"C:\Users\User\Ifeakachukwu_IT_Material\elephant.jpg")
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1200, 1920, 3)

# %%
plt.imshow(img)      # opencv image channel BGR
plt.show()

# %%
img
# Out:
# array([[[146, 157, 165],
#         [146, 157, 165],
#         [146, 157, 165],
#         ...,
#         [157, 163, 168],
#         [157, 163, 168],
#         [157, 163, 168]],
#
#        [[146, 157, 165],
#         [146, 157, 165],
#         [146, 157, 165],
#         ...,
#         [157, 163, 168],
#         [157, 163, 168],
#         [157, 163, 168]],
#
#        [[146, 157, 165],
#         [146, 157, 165],
#         [146, 157, 165],
#         ...,
#         [157, 163, 168],
#         [157, 163, 168],
#         [157, 163, 168]],
#
#        ...,
#
#        [[ 57, 141, 137],
#         [ 72, 156, 152],
#         [ 87, 168, 165],
#         ...,
#         [  0,  39,  33],
#         [  0,  37,  31],
#         [  0,  43,  37]],
#
#        [[ 58, 143, 139],
#         [ 64, 148, 144],
#         [ 68, 149, 146],
#         ...,
#         [ 15,  59,  53],
#         [  2,  46,  40],
#         [  0,  41,  35]],
#
#        [[ 72, 157, 153],
#         [ 63, 148, 144],
#         [ 54, 135, 132],
# ...

# %%
#fixing the image above to the original image 
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
fix_img.shape
# Out:
# (1200, 1920, 3)

# %%
plt.imshow(fix_img)
plt.show()

# %%
img2 = Image.open(r"C:\Users\User\Ifeakachukwu_IT_Material\dog.jpg")

# %%
type(img2)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img2_arr = np.asarray(img2)
img2_arr
# Out:
# array([[[ 79,  94,  37],
#         [ 82,  97,  40],
#         [ 86, 101,  44],
#         ...,
#         [ 77,  88,  22],
#         [ 77,  88,  22],
#         [ 76,  85,  20]],
#
#        [[ 79,  94,  37],
#         [ 81,  96,  39],
#         [ 84,  99,  42],
#         ...,
#         [ 70,  78,  19],
#         [ 79,  87,  28],
#         [ 85,  93,  34]],
#
#        [[ 80,  93,  37],
#         [ 81,  94,  38],
#         [ 82,  95,  39],
#         ...,
#         [ 82,  88,  40],
#         [101, 107,  61],
#         [114, 120,  74]],
#
#        ...,
#
#        [[100,  92,  45],
#         [105, 103,  54],
#         [117, 126,  73],
#         ...,
#         [ 59,  67,  26],
#         [ 62,  71,  26],
#         [ 80,  90,  40]],
#
#        [[138, 130,  83],
#         [106, 104,  55],
#         [100, 109,  56],
#         ...,
#         [148, 156, 115],
#         [ 91, 100,  55],
#         [ 75,  84,  37]],
#
#        [[149, 141,  94],
#         [ 85,  83,  34],
#         [ 69,  78,  25],
# ...

# %%
plt.imshow(img2)
plt.show()

# %%
img_gray = cv2.imread(r"C:\Users\User\Ifeakachukwu_IT_Material\elephant.jpg", cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (1200, 1920)

# %%
img_gray
# Out:
# array([[158, 158, 158, ..., 164, 164, 164],
#        [158, 158, 158, ..., 164, 164, 164],
#        [158, 158, 158, ..., 164, 164, 164],
#        ...,
#        [130, 145, 158, ...,  32,  30,  36],
#        [132, 137, 139, ...,  52,  39,  34],
#        [146, 137, 125, ...,  83,  63,  50]], dtype=uint8)

# %%
img_gray.min()
# Out:
# 0

# %%
img_gray.max()
# Out:
# 255

# %%
plt.imshow(img_gray)
plt.show()

# %%
plt.imshow(img_gray, cmap='gray')
plt.show()

# %%
plt.imshow(img_gray, cmap='Accent_r')
plt.show()

# %%
plt.imshow(img)
plt.show()

# %%
plt.imshow(fix_img)
plt.show()

# %%
fix_img.shape
# Out:
# (1200, 1920, 3)

# %%
# Resizing the image

# %%
fix_img_1 = cv2.resize(fix_img, (500,367))

# %%
fix_img_1.shape
# Out:
# (367, 500, 3)

# %%
w_ratio = 0.5     # width
h_ratio = 0.5     # height

# %%
fix_img_2 = cv2.resize(fix_img, (0,0), fix_img, w_ratio, h_ratio)

# %%
fix_img_2
# Out:
# array([[[165, 157, 146],
#         [166, 158, 147],
#         [166, 158, 147],
#         ...,
#         [168, 163, 157],
#         [168, 163, 157],
#         [168, 163, 157]],
#
#        [[165, 157, 146],
#         [165, 157, 146],
#         [166, 158, 147],
#         ...,
#         [168, 163, 157],
#         [168, 163, 157],
#         [168, 163, 157]],
#
#        [[164, 156, 145],
#         [164, 156, 145],
#         [165, 157, 146],
#         ...,
#         [169, 162, 156],
#         [169, 162, 156],
#         [169, 162, 156]],
#
#        ...,
#
#        [[121, 125,  41],
#         [138, 141,  60],
#         [152, 155,  76],
#         ...,
#         [ 78,  82,  25],
#         [ 59,  63,  11],
#         [ 38,  42,   0]],
#
#        [[144, 148,  64],
#         [164, 167,  86],
#         [142, 145,  66],
#         ...,
#         [ 55,  58,  12],
#         [ 40,  45,   2],
#         [ 37,  43,   1]],
#
#        [[145, 149,  64],
#         [135, 138,  57],
#         [125, 128,  51],
# ...

# %%
plt.imshow(fix_img_2)
plt.show()

# %%
img3 = cv2.flip(fix_img_2, 0)
plt.imshow(img3)
plt.show()

# %%
img3 = cv2.flip(fix_img_2, 1)
plt.imshow(img3)
plt.show()

# %%
img3 = cv2.flip(fix_img_2, 6)
plt.imshow(img3)
plt.show()

# %%
fix_img_2
# Out:
# array([[[165, 157, 146],
#         [166, 158, 147],
#         [166, 158, 147],
#         ...,
#         [168, 163, 157],
#         [168, 163, 157],
#         [168, 163, 157]],
#
#        [[165, 157, 146],
#         [165, 157, 146],
#         [166, 158, 147],
#         ...,
#         [168, 163, 157],
#         [168, 163, 157],
#         [168, 163, 157]],
#
#        [[164, 156, 145],
#         [164, 156, 145],
#         [165, 157, 146],
#         ...,
#         [169, 162, 156],
#         [169, 162, 156],
#         [169, 162, 156]],
#
#        ...,
#
#        [[121, 125,  41],
#         [138, 141,  60],
#         [152, 155,  76],
#         ...,
#         [ 78,  82,  25],
#         [ 59,  63,  11],
#         [ 38,  42,   0]],
#
#        [[144, 148,  64],
#         [164, 167,  86],
#         [142, 145,  66],
#         ...,
#         [ 55,  58,  12],
#         [ 40,  45,   2],
#         [ 37,  43,   1]],
#
#        [[145, 149,  64],
#         [135, 138,  57],
#         [125, 128,  51],
# ...

# %%
img3 = cv2.flip(fix_img_2, 0)
plt.imshow(img3)
plt.show()

# %%
cv2.imwrite('New Genai image.jpg', img3)     # to save the image
# Out:
# True

# %%
pwd
# Out:
# 'C:\\Users\\User\\Ifeakachukwu_IT_Material'
